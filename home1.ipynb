# %% [markdown]
# # TASK 1

# %%
# Write a Python function to find the max of any numbers of arguments (don't use the build in function max())
def find_maximum_number(*number):
    max_number = number[0]
    for numbers in number:
        if numbers > max_number:
            max_number = numbers
    return max_number 
    
print(find_maximum_number(10, 7, 2, 1, 2, 7, 52, 9))
# Out:
# 52

# %%
# Write a function that computes the volume of a sphere given its radius.
def find_volume(radius):
    pi = 3.14159
    volume = 4/3 * pi * radius ** 3
    return volume
print(find_volume(3))
# Out:
# 113.09723999999999

# %%
# Write a function that checks whether a number is in a given range (Inclusive of high and low)
def is_in_the_range(point, low, high) -> bool:
    return low <= point <= high
print(is_in_the_range(3, 4, 3))
# Out:
# False

# %%
# Write a Python function that accepts a string and calculate the number of upper case letters and lower case letters.
def count_uppercase_and_lowercase(letter: str) -> tuple:
    upper_count = 0
    lower_count = 0

    for char in letter:
        if char.isupper():
            upper_count += 1
        elif char.islower():
            lower_count += 1

    return upper_count, lower_count
print(count_uppercase_and_lowercase("ASDFAfafaFAFFafaFAFAFfaf"))
# Out:
# (14, 10)

# %%
# Write a Python function that takes a list and returns a new list with unique elements of the first list. Please use list comprehension as well
def make_a_unique_list(item: list) -> list:
    return [x for i, x in enumerate(item) if x not in item[:i]]
print(make_a_unique_list([1, 1, 1, 2, 2, 2, 3, 4, 4, 5, 6]))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# Write a Python function to check whether a string is pangram or not.
# Note : Pangrams are words or sentences containing every letter of the alphabet at least once. For example : "The quick brown fox jumps over the lazy dog"
def is_pangram(sentence: str) -> bool:
    alphabet = set('abcdefghijklmnopqrstuvwxyz')
    sentence_set = set(sentence.lower())

    return alphabet.issubset(sentence_set)
print(is_pangram("The quick brown fox jumps over the lazy dog"))
# Out:
# True

# %%
#Write a Python function to calculate the fibonacci number of index i (starts with 1). The function accepts the number as an argument and return a single number. The fibonacci sequence starts with 1,1,2,3,5,8,13,21,.... Therefore, fibonacci of index 6 is number 8.
def fibonacci(index_of_fibo_number: int) -> int:
    if index_of_fibo_number == 1:
        return 1
    else:
        a, b = 0, 1
        for _ in range(2, index_of_fibo_number + 1):
            a, b = b, a + b
        return b

# %%
# Create a function which finds the length of each word in the phrase (broken by spaces) and return the values in a list. The function will have an input of a string, and output a list of integers.
def find_length_of_words(word: str) -> list:
    return [len(w) for w in word.split()]

# %%
# Write a function that accepts a list of tuples containing the name of the student and their score, sort them by the score from high to low.
def sort_students(students: list) -> list:
    return sorted(students, key=lambda x: x[1], reverse=True)

# %%
# Write a python function that accepts a list of tuples of length 2, where each tuple contains student name and their scores respectively. The function should return the name of the student whose got maximum score. Please use map(), and max() function is strictly prohibited.
def top_student(students_list: list) -> str:
    scores = list(map(lambda x: x[1], students_list))

    highest = scores[0]

    for score in scores:
        if score > highest:
            highest = score

    for name, score in students_list:
        if score == highest:
            return name
